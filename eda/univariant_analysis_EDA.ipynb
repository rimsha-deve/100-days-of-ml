# %% [markdown]
# # 📊 Univariate Analysis — EDA
#
# **Dataset:** Train dataset (`train.csv`)
# **Goal:** Analyze each feature individually to understand distributions, spread and outliers
#
# ### What this notebook covers:
# - Histograms and KDE plots
# - Box plots for outlier detection
# - Value counts for categorical variables
# - Statistical summary per feature

# %% [markdown]
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt

# %%
df=pd.read_csv("train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## 1.Catagorical_Data

# %% [markdown]
# ## a.countplot

# %%
# sns.countplot(df['Survived'])
df['Survived'].value_counts().plot(kind='bar')
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
df['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
df['Embarked'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Embarked'>

# %% [markdown]
# ## b.Pie_chart

# %%
df['Embarked'].value_counts().plot(kind='pie',autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df['Survived'].value_counts().plot(kind='pie',autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df['Sex'].value_counts().plot(kind='pie',autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## 2nd Numerical Data

# %% [markdown]
# ## a.Histogram

# %%
plt.hist(df['Age'],bins=40,histtype='stepfilled')
# Out:
# (array([24., 16.,  7.,  7., 10.,  5.,  8., 23., 39., 40., 52., 46., 42.,
#         43., 47., 37., 32., 41., 18., 27., 21., 14., 17., 18., 16., 13.,
#          9.,  7.,  7.,  6.,  7.,  4.,  4.,  0.,  2.,  3.,  1.,  0.,  0.,
#          1.]),
#  array([ 0.42  ,  2.4095,  4.399 ,  6.3885,  8.378 , 10.3675, 12.357 ,
#         14.3465, 16.336 , 18.3255, 20.315 , 22.3045, 24.294 , 26.2835,
#         28.273 , 30.2625, 32.252 , 34.2415, 36.231 , 38.2205, 40.21  ,
#         42.1995, 44.189 , 46.1785, 48.168 , 50.1575, 52.147 , 54.1365,
#         56.126 , 58.1155, 60.105 , 62.0945, 64.084 , 66.0735, 68.063 ,
#         70.0525, 72.042 , 74.0315, 76.021 , 78.0105, 80.    ]),
#  [<matplotlib.patches.Polygon at 0x27687e64190>])

# %% [markdown]
# ## b.Distplot

# %%
## we used it as ti fnd the probablity of x_axis ..also it show kde (kernal_density estimation) simple it shows the pdf(probablity_density function)

# %%
sns.histplot(df['Age'],kde=True,stat='density')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## c.Boxplot

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Age'].max()
# Out:
# 80.0

# %%
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)
