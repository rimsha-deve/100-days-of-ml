# %% [markdown]
# # 🏠 Exploratory Data Analysis — Housing Dataset
#
# **Dataset:** California Housing Data (`Housing.csv`)
# **Goal:** Understand the data structure, distributions, missing values and relationships between features
#
# ### What this notebook covers:
# - Loading and inspecting the dataset
# - Checking shape, dtypes, missing values
# - Statistical summary
# - Visualizing distributions and correlations

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('housing.csv')

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.shape
# Out:
# (545, 13)

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
df.corr(numeric_only=True)['area']
# Out:
# price        0.535997
# area         1.000000
# bedrooms     0.151858
# bathrooms    0.193820
# stories      0.083996
# parking      0.352980
# Name: area, dtype: float64

# %%
df['guestroom'].value_counts()
# Out:
# guestroom
# no     448
# yes     97
# Name: count, dtype: int64

# %% [markdown]
# ## 📊 Visualizations
# Exploring feature distributions and relationships using Seaborn and Matplotlib

# %%
sns.countplot(df['guestroom'])
plt.title('Guestroom_availablity',color='b')
# Out:
# Text(0.5, 1.0, 'Guestroom_availablity')

# %%
df['guestroom'].value_counts().plot(kind='pie',autopct='%0.1f%%',explode=[0.0,0.1])
plt.title('Guestroom_availablity',color='b')
# Out:
# Text(0.5, 1.0, 'Guestroom_availablity')

# %%
df['mainroad'].value_counts()
# Out:
# mainroad
# yes    468
# no      77
# Name: count, dtype: int64

# %%
sns.countplot(df['mainroad'])
plt.title('Main_road availablity',color='b')
# Out:
# Text(0.5, 1.0, 'Main_road availablity')

# %%
df['mainroad'].value_counts().plot(kind='pie',autopct='%0.1f%%',explode=[0.0,0.4])
plt.title('Main_road availablity',color='b')
# Out:
# Text(0.5, 1.0, 'Main_road availablity')

# %%
df['basement'].value_counts()
# Out:
# basement
# no     354
# yes    191
# Name: count, dtype: int64

# %%
sns.countplot(df['basement'])
plt.title("Basement_availability",color='b')
# Out:
# Text(0.5, 1.0, 'Basement_availability')

# %%
df['basement'].value_counts().plot(kind='pie',autopct='%0.1f%%',explode=[0.0,0.1])
plt.title('Basement_availablitiy',color='b')
# Out:
# Text(0.5, 1.0, 'Basement_availablitiy')

# %%
df['hotwaterheating'].value_counts()
# Out:
# hotwaterheating
# no     520
# yes     25
# Name: count, dtype: int64

# %%
sns.countplot(df['hotwaterheating'])
plt.title('Hotwaterheating_availablity',color='b')
# Out:
# Text(0.5, 1.0, 'Hotwaterheating_availablity')

# %%
df['hotwaterheating'].value_counts().plot(kind='pie',autopct='%0.1f%%',explode=[0.0,0.3])
# Out:
# <Axes: ylabel='count'>

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
sns.countplot(df['airconditioning'])
plt.title('Airconditioning_AVAILABLITY')
# Out:
# Text(0.5, 1.0, 'Airconditioning_AVAILABLITY')

# %%
df['airconditioning'].value_counts().plot(kind='pie',autopct="%0.1f%%",explode=[0.0,0.1])
plt.title('Airconditioning_Availability',color='b')
# Out:
# Text(0.5, 1.0, 'Airconditioning_Availability')

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
sns.countplot(df['furnishingstatus'])
# Out:
# <Axes: xlabel='count', ylabel='furnishingstatus'>

# %%
df['furnishingstatus'].value_counts().plot(kind='pie',autopct='%0.1f%%',explode=[0.0,0.2,0.1])
# Out:
# <Axes: ylabel='count'>

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
plt.hist(df['price'])
# Out:
# (array([ 61., 163., 139.,  89.,  46.,  25.,  13.,   4.,   1.,   4.]),
#  array([ 1750000.,  2905000.,  4060000.,  5215000.,  6370000.,  7525000.,
#          8680000.,  9835000., 10990000., 12145000., 13300000.]),
#  <BarContainer object of 10 artists>)

# %%
sns.displot(data=df['price'],kde=True,stat='density')

# %%
df['price'].mean()
# Out:
# np.float64(4766729.247706422)

# %%
df['price'].median()
# Out:
# 4340000.0

# %%
plt.boxplot(df['price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2135a47f890>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2135a47fb10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2135a47f750>],
#  'medians': [<matplotlib.lines.Line2D at 0x2135a47fd90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2135a47fed0>],
#  'means': []}

# %%
## Price distribution is right skewed.
# Mean (4.77M) > Median (4.34M) confirms this.
#A log transformation will be needed before ML modeling.

# %%
plt.hist(df['area'])
# Out:
# (array([ 73., 198., 117.,  88.,  39.,  15.,   8.,   5.,   0.,   2.]),
#  array([ 1650.,  3105.,  4560.,  6015.,  7470.,  8925., 10380., 11835.,
#         13290., 14745., 16200.]),
#  <BarContainer object of 10 artists>)

# %%
sns.displot(data=df['area'],kde=True,stat='density')

# %%
## price increase with the area

# %%
df.corr(numeric_only=True)['price']['area']
# Out:
# np.float64(0.5359973457780797)

# %%
sns.scatterplot(x='area',y='price',data=df)
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
# Area vs Price correlation = 0.54 (moderate)
# Area is important but not the only factor 
# driving house prices.

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
plt.hist(df['bedrooms'])
plt.title('Bedroms_count')
# Out:
# Text(0.5, 1.0, 'Bedroms_count')

# %%
df['bedrooms'].mean()
# Out:
# np.float64(2.9651376146788992)

# %%
sns.displot(data=df['bedrooms'],kde=True,stat='density')

# %%
plt.boxplot(df['bedrooms'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2135c43ed50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2135c43efd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2135c43ec10>],
#  'medians': [<matplotlib.lines.Line2D at 0x2135c43f250>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2135c43f390>],
#  'means': []}

# %%
df.corr(numeric_only=True)['price']['bedrooms']
# Out:
# np.float64(0.36649402577386964)

# %%
sns.scatterplot(x='bedrooms',y='price',data=df)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
plt.hist(df['bathrooms'])
plt.title('Bathroom_count')
# Out:
# Text(0.5, 1.0, 'Bathroom_count')

# %%
df['bathrooms'].value_counts().plot(kind='pie',autopct='%0.1f%%',explode=[0.0,0.0,0.6,0.8])
# Out:
# <Axes: ylabel='count'>

# %%
sns.scatterplot(x='bathrooms',y='price',data=df)
# Out:
# <Axes: xlabel='bathrooms', ylabel='price'>

# %%
sns.displot(df['bathrooms'],kde=True,stat='density')

# %%
plt.boxplot(df['bathrooms'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2135c4a5f90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2135c4a6210>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2135c4a5e50>],
#  'medians': [<matplotlib.lines.Line2D at 0x2135c4a6490>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2135c4a65d0>],
#  'means': []}

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
plt.hist(df['stories'])
plt.title('no_of stories')
# Out:
# Text(0.5, 1.0, 'no_of stories')

# %%
df['stories'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.displot(df['stories'],kde=True,stat='density')

# %%
df['stories'].value_counts()
# Out:
# stories
# 2    238
# 1    227
# 4     41
# 3     39
# Name: count, dtype: int64

# %%
df.corr(numeric_only=True)['price']['stories']
# Out:
# np.float64(0.42071236618861724)

# %%
sns.boxplot(x='stories',y='bathrooms',data=df)
# Out:
# <Axes: xlabel='stories', ylabel='bathrooms'>

# %%
sns.scatterplot(x='stories',y='price',data=df)
# Out:
# <Axes: xlabel='stories', ylabel='price'>

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
plt.hist(df['parking'])
plt.title('parking_availablikty')
# Out:
# Text(0.5, 1.0, 'parking_availablikty')

# %%
sns.displot(df['parking'],kde=True,stat='density')

# %%
df['parking'].value_counts()
# Out:
# parking
# 0    299
# 1    126
# 2    108
# 3     12
# Name: count, dtype: int64

# %%
df.corr(numeric_only=True)['price']['parking']
# Out:
# np.float64(0.38439364863572645)

# %%
df.corr(numeric_only=True)['price'].sort_values(ascending=False)
# Out:
# price        1.000000
# area         0.535997
# bathrooms    0.517545
# stories      0.420712
# parking      0.384394
# bedrooms     0.366494
# Name: price, dtype: float64

# %%
sns.pairplot(df,vars=['price','area','bathrooms','stories','parking','bedrooms'])
