# %%
import pandas as pd
import requests

# %% [raw]
# import requests
#
# url = "https://api.themoviedb.org/3/trending/movie/day?api_key="a4ede86cf2aeb24ec762109605f24e69"
#
# try:
#     response = requests.get(url, timeout=10)
#     print("Status Code:", response.status_code)
#     print("Response Text:", response.text[:300])
# except Exception as e:
#     print("Error:", e)

# %% [raw]
# pip install requests

# %%
print("jupyter")
# Out:
# jupyter

# %%
print("hellooo")
# Out:
# hellooo

# %%
1+1
# Out:
# 2

# %%
3+6
# Out:
# 9
